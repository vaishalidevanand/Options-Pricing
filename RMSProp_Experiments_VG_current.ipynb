# %% [markdown]
# Adding Necessary Libraries and Functions:

# %%
import numpy as np
import tensorflow as tf
import time
import datetime
from scipy import stats
import math
import os
from math import log, sqrt, exp, pi, gamma
from numpy import sign
from scipy.integrate import quad
from scipy.stats import norm
from scipy.special import kv
import itertools

import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from scipy.stats.distributions import norm
from sklearn.model_selection import train_test_split

#import google.datalab.storage as storage
#from io import BytesIO
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow==1.13.1

# %%
# %run '/content/drive/My Drive/Colab Notebooks/codes/xavier_neural_networks-3-4.py'

# %% [markdown]
# ### Uniform Data Model:

# %% [markdown]
# Retrieving Data Files From Drive:

# %%
#Retrieve data files from Google Drive:
X_test=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_test_VG_EEP_uniform')
y_test=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_test_VG_EEP_uniform')
y_test=y_test.reshape(len(y_test),1)
euroP_test=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_test_VG_EEP_uniform')
euroP_test=euroP_test.reshape(len(euroP_test),1)
X_train=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_train_VG_EEP_uniform')
y_train=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_train_VG_EEP_uniform')
y_train=y_train.reshape(len(y_train),1)
euroP_train=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_train_VG_EEP_uniform')
euroP_train=euroP_train.reshape(len(euroP_train),1)
X_val=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_val_VG_EEP_uniform')
y_val=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_val_VG_EEP_uniform')
y_val=y_val.reshape(len(y_val),1)
euroP_val=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_val_VG_EEP_uniform')
euroP_val=euroP_val.reshape(len(euroP_val),1)
X_data_H=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_data_H_VG_EEP_uniform')
y_data_H=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_data_H_VG_EEP_uniform')
y_data_H=y_data_H.reshape(len(y_data_H),1)
euroP_data_H=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_data_H_VG_EEP_uniform')
euroP_data_H=euroP_data_H.reshape(len(euroP_data_H),1)

# %% [markdown]
# Experiments Without European Prices:

# %% [markdown]
# 1 Layer & 15 Neurons:

# %%
W,B,_=buildNN(1, ['leaky'], [15], 0.001, 100, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_uniform')
results=interpolation_new(2,1,['leaky'],[15],X_test,y_test,Layer_index=2,model='VG_EEP_uniform')
buildNN_tune(1, ['leaky'], [15], 0.0001, 20, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_uniform')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000057 total validation loss: 0.00000027
# Epoch:10 average loss: 0.00000058 total validation loss: 0.00000029
# Epoch:15 average loss: 0.00000058 total validation loss: 0.00000036
# Epoch:20 average loss: 0.00000057 total validation loss: 0.00000030
# Epoch:25 average loss: 0.00000055 total validation loss: 0.00000029
# Epoch:30 average loss: 0.00000055 total validation loss: 0.00000037
# Epoch:35 average loss: 0.00000056 total validation loss: 0.00000027
# Epoch:40 average loss: 0.00000057 total validation loss: 0.00000029
# Epoch:45 average loss: 0.00000056 total validation loss: 0.00000027
# Epoch:50 average loss: 0.00000057 total validation loss: 0.00000026
# Epoch:55 average loss: 0.00000057 total validation loss: 0.00000031
# Epoch:60 average loss: 0.00000056 total validation loss: 0.00000035
# Epoch:65 average loss: 0.00000057 total validation loss: 0.00000052
# ...

# %%
y_pred,_=prediction(X_test,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_1layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_uniform',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_1layers_15neurons_result_2
# Average Prediction Time : 10.96129417 microseconds
# Mean Squared Error:       0.000000205
# Mean Absolute Error:       0.000178892
# R2:    79.426416322
# (2.0510030092346868e-07, 0.00017889207961020053, 79.42641632225667)

# %%
y_pred,_=prediction(X_train,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_1layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_uniform',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_1layers_15neurons_result_2
# Average Prediction Time : 3.44408000 microseconds
# Mean Squared Error:       0.000000205
# Mean Absolute Error:       0.000177475
# R2:    79.742044902
# (2.0507868881964608e-07, 0.00017747490590902797, 79.74204490192254)

# %% [markdown]
# 2 Layers & 15 Neurons:

# %%
W,B,_=buildNN(2, ['leaky','leaky'], [15,15], 0.001, 100, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_uniform')
results=interpolation_new(2,2,['leaky','leaky'], [15,15],X_test,y_test,Layer_index=2,model='VG_EEP_uniform')
buildNN_tune(2, ['leaky','leaky'], [15,15], 0.0001, 20, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_uniform')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000054 total validation loss: 0.00000033
# Epoch:10 average loss: 0.00000050 total validation loss: 0.00000019
# Epoch:15 average loss: 0.00000051 total validation loss: 0.00000046
# Epoch:20 average loss: 0.00000050 total validation loss: 0.00000022
# Epoch:25 average loss: 0.00000051 total validation loss: 0.00000022
# Epoch:30 average loss: 0.00000046 total validation loss: 0.00000016
# Epoch:35 average loss: 0.00000049 total validation loss: 0.00000032
# Epoch:40 average loss: 0.00000049 total validation loss: 0.00000027
# Epoch:45 average loss: 0.00000047 total validation loss: 0.00000019
# Epoch:50 average loss: 0.00000046 total validation loss: 0.00000020
# Epoch:55 average loss: 0.00000044 total validation loss: 0.00000017
# Epoch:60 average loss: 0.00000044 total validation loss: 0.00000025
# Epoch:65 average loss: 0.00000043 total validation loss: 0.00000016
# ...

# %%
y_pred,_=prediction(X_test,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_2layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky','leaky'],model='VG_EEP_uniform',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_2layers_15neurons_result_2
# Average Prediction Time : 21.66787783 microseconds
# Mean Squared Error:       0.000000202
# Mean Absolute Error:       0.000167676
# R2:    79.699600634
# (2.023768967078101e-07, 0.00016767603556704026, 79.69960063386856)

# %%
y_pred,_=prediction(X_train,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_2layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky','leaky'],model='VG_EEP_uniform',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_2layers_15neurons_result_2
# Average Prediction Time : 4.22905993 microseconds
# Mean Squared Error:       0.000000202
# Mean Absolute Error:       0.000167399
# R2:    80.029507302
# (2.021686018014303e-07, 0.0001673994521994518, 80.02950730226175)

# %% [markdown]
# Experiments with European Prices:

# %%
X_test_euroP = np.hstack((X_test,euroP_test))
X_train_euroP = np.hstack((X_train,euroP_train))
X_val_euroP = np.hstack((X_val,euroP_val))
X_data_H_euroP = np.hstack((X_data_H,euroP_data_H))

# %% [markdown]
# 1 Layer & 15 Neurons:

# %%
W,B,_=buildNN(1, ['leaky'], [15], 0.001, 100, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_uniform_euro')
results=interpolation_new(2,1,['leaky'],[15],X_test_euroP,y_test,Layer_index=2,model='VG_EEP_uniform_euro')
buildNN_tune(1, ['leaky'], [15], 0.0001, 20, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_uniform_euro')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000058 total validation loss: 0.00000028
# Epoch:10 average loss: 0.00000055 total validation loss: 0.00000026
# Epoch:15 average loss: 0.00000056 total validation loss: 0.00000032
# Epoch:20 average loss: 0.00000056 total validation loss: 0.00000031
# Epoch:25 average loss: 0.00000057 total validation loss: 0.00000032
# Epoch:30 average loss: 0.00000056 total validation loss: 0.00000034
# Epoch:35 average loss: 0.00000057 total validation loss: 0.00000051
# Epoch:40 average loss: 0.00000056 total validation loss: 0.00000028
# Epoch:45 average loss: 0.00000055 total validation loss: 0.00000027
# Epoch:50 average loss: 0.00000055 total validation loss: 0.00000048
# Epoch:55 average loss: 0.00000057 total validation loss: 0.00000046
# Epoch:60 average loss: 0.00000054 total validation loss: 0.00000027
# Epoch:65 average loss: 0.00000056 total validation loss: 0.00000032
# ...

# %%
y_pred,_=prediction(X_test_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_1layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_uniform_euro',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_1layers_15neurons_result_2
# Average Prediction Time : 10.09442012 microseconds
# Mean Squared Error:       0.000000200
# Mean Absolute Error:       0.000174109
# R2:    79.916276138
# (2.0021683495912178e-07, 0.0001741088325899069, 79.91627613817373)

# %%
y_pred,_=prediction(X_train_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_1layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_uniform_euro',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_1layers_15neurons_result_2
# Average Prediction Time : 3.10576845 microseconds
# Mean Squared Error:       0.000000200
# Mean Absolute Error:       0.000172961
# R2:    80.222361301
# (2.0021627023433693e-07, 0.00017296070814667425, 80.2223613011359)

# %% [markdown]
# 2 Layers & 15 Neurons:

# %%
W,B,_=buildNN(2, ['leaky','leaky'], [15,15], 0.001, 100, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_uniform_euro')
results=interpolation_new(2,2,['leaky','leaky'],[15,15],X_test_euroP,y_test,Layer_index=2,model='VG_EEP_uniform_euro')
buildNN_tune(2, ['leaky','leaky'], [15,15], 0.0001, 20, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_uniform_euro')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000056 total validation loss: 0.00000033
# Epoch:10 average loss: 0.00000051 total validation loss: 0.00000029
# Epoch:15 average loss: 0.00000052 total validation loss: 0.00000043
# Epoch:20 average loss: 0.00000051 total validation loss: 0.00000025
# Epoch:25 average loss: 0.00000049 total validation loss: 0.00000017
# Epoch:30 average loss: 0.00000049 total validation loss: 0.00000019
# Epoch:35 average loss: 0.00000049 total validation loss: 0.00000020
# Epoch:40 average loss: 0.00000048 total validation loss: 0.00000037
# Epoch:45 average loss: 0.00000049 total validation loss: 0.00000045
# Epoch:50 average loss: 0.00000047 total validation loss: 0.00000025
# Epoch:55 average loss: 0.00000048 total validation loss: 0.00000019
# Epoch:60 average loss: 0.00000045 total validation loss: 0.00000024
# Epoch:65 average loss: 0.00000046 total validation loss: 0.00000028
# ...

# %%
y_pred,_=prediction(X_test_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_2layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky','leaky'],model='VG_EEP_uniform_euro',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_2layers_15neurons_result_2
# Average Prediction Time : 13.83304596 microseconds
# Mean Squared Error:       0.000000185
# Mean Absolute Error:       0.000161714
# R2:    81.443923738
# (1.8498754931765802e-07, 0.0001617135908497651, 81.44392373832923)

# %%
y_pred,_=prediction(X_train_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_2layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky','leaky'],model='VG_EEP_uniform_euro',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_uniform_euro_2layers_15neurons_result_2
# Average Prediction Time : 6.26773746 microseconds
# Mean Squared Error:       0.000000184
# Mean Absolute Error:       0.000160883
# R2:    81.861209619
# (1.8362560929768125e-07, 0.00016088262894190772, 81.8612096194893)

# %% [markdown]
# ### Halton Sequence Data Model:

# %% [markdown]
# Retrieving Data Files From Drive:

# %%
#Retrieve data files from Google Drive:
X_test=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_test_VG_EEP_Halton')
y_test=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_test_VG_EEP_Halton')
y_test=y_test.reshape(len(y_test),1)
euroP_test=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_test_VG_EEP_Halton')
euroP_test=euroP_test.reshape(len(euroP_test),1)
X_train=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_train_VG_EEP_Halton')
y_train=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_train_VG_EEP_Halton')
y_train=y_train.reshape(len(y_train),1)
euroP_train=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_train_VG_EEP_Halton')
euroP_train=euroP_train.reshape(len(euroP_train),1)
X_val=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_val_EEP_VG_Halton')
y_val=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_val_EEP_VG_Halton')
y_val=y_val.reshape(len(y_val),1)
euroP_val=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_val_EEP_VG_Halton')
euroP_val=euroP_val.reshape(len(euroP_val),1)
X_data_H=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/X_data_H_EEP_VG_Halton')
y_data_H=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/y_data_H_EEP_VG_Halton')
y_data_H=y_data_H.reshape(len(y_data_H),1)
euroP_data_H=np.loadtxt('/content/drive/My Drive/Colab Notebooks/data_export/euroP_data_H_VG_EEP_Halton')
euroP_data_H=euroP_data_H.reshape(len(euroP_data_H),1)

# %% [markdown]
# Experiments Without European Prices:

# %% [markdown]
# 1 Layer & 15 Neurons:

# %%
W,B,_=buildNN(1, ['leaky'], [15], 0.001, 100, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_Halton')
results=interpolation_new(2,1,['leaky'],[15],X_test,y_test,Layer_index=2,model='VG_EEP_Halton')
buildNN_tune(1, ['leaky'], [15], 0.0001, 20, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_Halton')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000051 total validation loss: 0.00000026
# Epoch:10 average loss: 0.00000049 total validation loss: 0.00000025
# Epoch:15 average loss: 0.00000049 total validation loss: 0.00000022
# Epoch:20 average loss: 0.00000046 total validation loss: 0.00000027
# Epoch:25 average loss: 0.00000049 total validation loss: 0.00000025
# Epoch:30 average loss: 0.00000049 total validation loss: 0.00000025
# Epoch:35 average loss: 0.00000049 total validation loss: 0.00000085
# Epoch:40 average loss: 0.00000047 total validation loss: 0.00000026
# Epoch:45 average loss: 0.00000048 total validation loss: 0.00000022
# Epoch:50 average loss: 0.00000047 total validation loss: 0.00000022
# Epoch:55 average loss: 0.00000048 total validation loss: 0.00000020
# Epoch:60 average loss: 0.00000048 total validation loss: 0.00000026
# Epoch:65 average loss: 0.00000047 total validation loss: 0.00000022
# ...

# %%
y_pred,_=prediction(X_test,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_1layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_Halton',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_1layers_15neurons_result_2
# Average Prediction Time : 10.30476888 microseconds
# Mean Squared Error:       0.000000189
# Mean Absolute Error:       0.000169624
# R2:    81.000584588
# (1.8940724568732048e-07, 0.00016962394929626197, 81.00058458825457)

# %%
y_pred,_=prediction(X_train,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_1layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_Halton',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_1layers_15neurons_result_2
# Average Prediction Time : 4.69792772 microseconds
# Mean Squared Error:       0.000000188
# Mean Absolute Error:       0.000168100
# R2:    81.404482586
# (1.8824922410092252e-07, 0.00016809974743023254, 81.40448258649545)

# %% [markdown]
# 2 Layers & 15 Neurons:

# %%
W,B,_=buildNN(2, ['leaky','leaky'], [15,15], 0.001, 100, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_Halton')
results=interpolation_new(2,2,['leaky','leaky'],[15,15],X_test,y_test,Layer_index=2,model='VG_EEP_Halton')
buildNN_tune(2, ['leaky','leaky'], [15,15], 0.0001, 20, 50, 2, 0.5, X_train, y_train, X_test, y_test, X_val, y_val, X_data_H, y_data_H,2,'VG_EEP_Halton')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000049 total validation loss: 0.00000023
# Epoch:10 average loss: 0.00000045 total validation loss: 0.00000035
# Epoch:15 average loss: 0.00000044 total validation loss: 0.00000021
# Epoch:20 average loss: 0.00000044 total validation loss: 0.00000017
# Epoch:25 average loss: 0.00000042 total validation loss: 0.00000017
# Epoch:30 average loss: 0.00000042 total validation loss: 0.00000015
# Epoch:35 average loss: 0.00000038 total validation loss: 0.00000012
# Epoch:40 average loss: 0.00000041 total validation loss: 0.00000011
# Epoch:45 average loss: 0.00000042 total validation loss: 0.00000021
# Epoch:50 average loss: 0.00000041 total validation loss: 0.00000012
# Epoch:55 average loss: 0.00000042 total validation loss: 0.00000015
# Epoch:60 average loss: 0.00000041 total validation loss: 0.00000012
# Epoch:65 average loss: 0.00000039 total validation loss: 0.00000030
# ...

# %%
y_pred,_=prediction(X_test,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_2layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky'],model='VG_EEP_Halton',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_2layers_15neurons_result_2
# Average Prediction Time : 18.23515892 microseconds
# Mean Squared Error:       0.000000164
# Mean Absolute Error:       0.000150269
# R2:    83.533123461
# (1.6416008928095706e-07, 0.00015026918524879956, 83.53312346124827)

# %%
y_pred,_=prediction(X_train,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_2layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky'],model='VG_EEP_Halton',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_2layers_15neurons_result_2
# Average Prediction Time : 4.45668786 microseconds
# Mean Squared Error:       0.000000164
# Mean Absolute Error:       0.000149239
# R2:    83.814758159
# (1.6384912291743713e-07, 0.00014923856630866231, 83.81475815929423)

# %% [markdown]
# Experiments With European Prices:

# %%
X_test_euroP = np.hstack((X_test,euroP_test))
X_train_euroP = np.hstack((X_train,euroP_train))
X_val_euroP = np.hstack((X_val,euroP_val))
X_data_H_euroP = np.hstack((X_data_H,euroP_data_H))

# %% [markdown]
# 1 Layer & 15 Neurons:

# %%
W,B,_=buildNN(1, ['leaky'], [15], 0.001, 100, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_Halton_euro')
results=interpolation_new(2,1,['leaky'],[15],X_test_euroP,y_test,Layer_index=2,model='VG_EEP_Halton_euro')
buildNN_tune(1, ['leaky'], [15], 0.0001, 20, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_Halton_euro')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000049 total validation loss: 0.00000035
# Epoch:10 average loss: 0.00000047 total validation loss: 0.00000024
# Epoch:15 average loss: 0.00000045 total validation loss: 0.00000032
# Epoch:20 average loss: 0.00000048 total validation loss: 0.00000025
# Epoch:25 average loss: 0.00000047 total validation loss: 0.00000023
# Epoch:30 average loss: 0.00000045 total validation loss: 0.00000021
# Epoch:35 average loss: 0.00000047 total validation loss: 0.00000021
# Epoch:40 average loss: 0.00000046 total validation loss: 0.00000023
# Epoch:45 average loss: 0.00000047 total validation loss: 0.00000022
# Epoch:50 average loss: 0.00000048 total validation loss: 0.00000022
# Epoch:55 average loss: 0.00000046 total validation loss: 0.00000042
# Epoch:60 average loss: 0.00000046 total validation loss: 0.00000023
# Epoch:65 average loss: 0.00000046 total validation loss: 0.00000022
# ...

# %%
y_pred,_=prediction(X_test_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_1layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_Halton_euro',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_1layers_15neurons_result_2
# Average Prediction Time : 15.48585892 microseconds
# Mean Squared Error:       0.000000182
# Mean Absolute Error:       0.000165452
# R2:    81.729294731
# (1.8214265475170993e-07, 0.00016545210188545283, 81.72929473068447)

# %%
y_pred,_=prediction(X_train_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_1layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=1,TypeLayers=['leaky'],model='VG_EEP_Halton_euro',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_1layers_15neurons_result_2
# Average Prediction Time : 2.94385574 microseconds
# Mean Squared Error:       0.000000180
# Mean Absolute Error:       0.000163725
# R2:    82.239071718
# (1.7980037306958872e-07, 0.00016372452798073386, 82.23907171815128)

# %% [markdown]
# 2 Layers & 15 Neurons:

# %%
W,B,_=buildNN(2, ['leaky','leaky'], [15,15], 0.001, 100, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_Halton_euro')
results=interpolation_new(2,2,['leaky','leaky'],[15,15],X_test_euroP,y_test,Layer_index=2,model='VG_EEP_Halton_euro')
buildNN_tune(2, ['leaky','leaky'], [15,15], 0.0001, 20, 50, 2, 0.5, X_train_euroP, y_train, X_test_euroP, y_test, X_val_euroP, y_val, X_data_H_euroP, y_data_H,2,'VG_EEP_Halton_euro')
# Out:
# Train on 54000 samples, validate on 6000 samples, test on 15000 samples
# Epoch: 5 average loss: 0.00000055 total validation loss: 0.00000027
# Epoch:10 average loss: 0.00000050 total validation loss: 0.00000027
# Epoch:15 average loss: 0.00000050 total validation loss: 0.00000026
# Epoch:20 average loss: 0.00000050 total validation loss: 0.00000019
# Epoch:25 average loss: 0.00000051 total validation loss: 0.00000021
# Epoch:30 average loss: 0.00000050 total validation loss: 0.00000019
# Epoch:35 average loss: 0.00000046 total validation loss: 0.00000021
# Epoch:40 average loss: 0.00000046 total validation loss: 0.00000027
# Epoch:45 average loss: 0.00000043 total validation loss: 0.00000017
# Epoch:50 average loss: 0.00000046 total validation loss: 0.00000021
# Epoch:55 average loss: 0.00000046 total validation loss: 0.00000046
# Epoch:60 average loss: 0.00000044 total validation loss: 0.00000016
# Epoch:65 average loss: 0.00000044 total validation loss: 0.00000021
# ...

# %%
y_pred,_=prediction(X_test_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_2layers_15neurons_result_2")
Analysis(y_test,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky','leaky'],model='VG_EEP_Halton_euro',data='Test')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_2layers_15neurons_result_2
# Average Prediction Time : 13.56603305 microseconds
# Mean Squared Error:       0.000000181
# Mean Absolute Error:       0.000162180
# R2:    81.845709884
# (1.8098209938291836e-07, 0.00016217977672536928, 81.8457098840752)

# %%
y_pred,_=prediction(X_train_euroP,path="/content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_2layers_15neurons_result_2")
Analysis(y_train,y_pred,numNeurons=15,numLayers=2,TypeLayers=['leaky','leaky'],model='VG_EEP_Halton_euro',data='Train')
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/Colab Notebooks/Neural_Networks/model_VG_EEP_Halton_euro_2layers_15neurons_result_2
# Average Prediction Time : 5.65808349 microseconds
# Mean Squared Error:       0.000000181
# Mean Absolute Error:       0.000161193
# R2:    82.157494651
# (1.8062620755554546e-07, 0.00016119294623172104, 82.15749465116669)
